# %%
# !pip install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.6.1.tar.gz (7.0MB)
#     100% |████████████████████████████████| 7.0MB 194kB/s
# Requirement already satisfied (use --upgrade to upgrade): pandas in /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages (from statsmodels)
# Collecting patsy (from statsmodels)
#   Downloading patsy-0.4.1-py2.py3-none-any.whl (233kB)
#     100% |████████████████████████████████| 235kB 4.3MB/s
# Requirement already satisfied (use --upgrade to upgrade): pytz>=2011k in /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages (from pandas->statsmodels)
# Requirement already satisfied (use --upgrade to upgrade): python-dateutil>=2 in /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages (from pandas->statsmodels)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.7.0 in /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages (from pandas->statsmodels)
# Requirement already satisfied (use --upgrade to upgrade): six in /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages (from patsy->statsmodels)
# Building wheels for collected packages: statsmodels
# done
#   Stored in directory: /Users/gcg/Library/Caches/pip/wheels/38/d3/1e/94a59b1460b3249b15399e09dae7a3828045bcf830d999b4b1
# Successfully built statsmodels
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.4.1 statsmodels-0.6.1

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt # package for doing plotting (necessary for adding the line)
import statsmodels.formula.api as smf # package we'll be using for linear regression

# %%
df = pd.read_csv("data/heights_weights_genders.csv")

# %%
df.plot(kind="scatter",x="Height",y="Weight")

# %%
lm = smf.ols(formula="Weight~Height",data=df).fit() #notice the formula regresses Y on X (Y~X)

# %%
lm.params #get the parameters from the model fit
# Intercept: when x is 0, y is -350
# Height: For every inch of height, you increase by 7.7 (=slope)
# Out:
# Intercept   -350.737192
# Height         7.717288
# dtype: float64

# %%
intercept, slope = lm.params #assign those values to variables

# %%
df.plot(kind="scatter",x="Height",y="Weight")
plt.plot(df["Height"],slope*df["Height"]+intercept,"-",color="red") #we create the best fit line from the values in the fit model
#plt.plot(x, y=mx+b, style)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Weight   R-squared:                       0.855
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                 5.904e+04
# Date:                Tue, 26 Jul 2016   Prob (F-statistic):               0.00
# Time:                        11:56:57   Log-Likelihood:                -39219.
# No. Observations:               10000   AIC:                         7.844e+04
# Df Residuals:                    9998   BIC:                         7.846e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   -350.7372      2.111   -166.109      0.000      -354.876  -346.598
# Height         7.7173      0.032    242.975      0.000         7.655     7.780
# ==============================================================================
# Omnibus:                        2.141   Durbin-Watson:                   1.677
# Prob(Omnibus):                  0.343   Jarque-Bera (JB):                2.150
# Skew:                           0.036   Prob(JB):                        0.341
# Kurtosis:                       2.991   Cond. No.                     1.15e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
