# %%
import pandas as pd
# %matplotlib inline

# %%
import matplotlib.pyplot as plt # package for doing plotting (necessary for adding the line)
import statsmodels.formula.api as smf

# %%
df = pd.read_csv("data/ontime_reports_may_2015_ny.csv")

# %%
df.corr()['DEP_DELAY'].sort_values(ascending=False)
# Out:
# DEP_DELAY              1.000000
# ARR_DELAY              0.945356
# LATE_AIRCRAFT_DELAY    0.534286
# CARRIER_DELAY          0.530374
# NAS_DELAY              0.300172
# WEATHER_DELAY          0.204236
# DAY_OF_MONTH           0.096697
# DIVERTED               0.039431
# CANCELLED              0.024350
# ACTUAL_ELAPSED_TIME    0.017203
# AIR_TIME               0.002656
# DISTANCE              -0.001030
# SECURITY_DELAY        -0.006269
# FL_NUM                -0.010442
# YEAR                        NaN
# MONTH                       NaN
# Unnamed: 20                 NaN
# Name: DEP_DELAY, dtype: float64

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(df[[ u'DEP_DELAY', u'ARR_DELAY', u'ACTUAL_ELAPSED_TIME',
       u'CARRIER_DELAY', u'WEATHER_DELAY', u'NAS_DELAY', u'SECURITY_DELAY',
       u'LATE_AIRCRAFT_DELAY']],alpha=0.2, figsize=(20, 20), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10f28fb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f2b6908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1097d2be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d4c7320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d501f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d552978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d58cba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d5db7b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10d618710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d661668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d6a3550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d6eb780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10d852c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10da113c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10da5ada0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10da9b400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10dae3fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10db10a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10db65358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10db70ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e4d4d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e523780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e55ef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e5ac9b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10e5e8cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e6998d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10e74b908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ee4e860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ee8b748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10eed9978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ef21d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ef644e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10efadeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10efee5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f03e208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f07a240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f0c2198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f103080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f14d2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f1976a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10f1d2dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f2217f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f2c4b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f30eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f3509b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f39aac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f3be710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f423a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10f46de10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f4ae4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f4f6ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f5392b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f583400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f5c40f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f60d320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f656710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10f690e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f6e0860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f71cf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f76ab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f7a7ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f7efb00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f82c9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f87ac18>]], dtype=object)

# %%
lm = smf.ols(formula="DEP_DELAY ~ LATE_AIRCRAFT_DELAY + CARRIER_DELAY + NAS_DELAY",data=df).fit()

# %%
#response variable = departure_variable
#explanatory variables = carrier delay, nas_delay, late_aircraft_delay
# --> thee variables for multiple regression

# %%
lm.params
# Out:
# Intercept              2.040708
# LATE_AIRCRAFT_DELAY    1.054917
# CARRIER_DELAY          1.020974
# NAS_DELAY              0.820646
# dtype: float64

# %%
#General: 2 min delay
#for every minute in late_arcraft_delay, we would expect 1.05 min of departure_delay

# %%
lm = smf.ols(formula="ARR_DELAY ~ LATE_AIRCRAFT_DELAY + CARRIER_DELAY + NAS_DELAY",data=df).fit()

# %%
lm.params
# Out:
# Intercept              4.111647
# LATE_AIRCRAFT_DELAY    0.994142
# CARRIER_DELAY          0.976219
# NAS_DELAY              0.982700
# dtype: float64
