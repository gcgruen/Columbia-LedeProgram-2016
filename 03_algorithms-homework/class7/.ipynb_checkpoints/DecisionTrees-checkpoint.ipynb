# %%
import pandas as pd
# %matplotlib inline

# %%
from sklearn import datasets
from pandas.tools.plotting import scatter_matrix

# %%
import matplotlib.pyplot as plt

# %%
iris = datasets.load_iris() # load iris data set

# %%
x = iris.data[:,2:] # the attributes
y = iris.target # the target variable

# %%
plt.figure(2, figsize=(8, 6))
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.CMRmap)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

# %%
plt.figure(2, figsize=(8, 6))
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.CMRmap)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.axhline(y=0.8)

# %%
plt.figure(2, figsize=(8, 6))
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.CMRmap)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.axhline(y=0.8)
plt.axvline(x=2.5)

# %% [markdown]
# ## How do we separate the other two categories?

# %%
plt.figure(2, figsize=(8, 6))
plt.scatter(x[:, 0], x[:, 1], c=y, cmap=plt.cm.CMRmap)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.axhline(y=0.8)
plt.axvline(x=2.5)
#add additional lines to make the cuts

# %% [markdown]
# # Wouldn't it be great if the machine could do this for us?

# %%
from sklearn import tree

# %%
dt = tree.DecisionTreeClassifier()

# %%
dt = dt.fit(x,y)

# %% [markdown]
# ## Now what?

# %%
# !pip3 install pydotplus
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278kB)
#     100% |████████████████████████████████| 286kB 3.7MB/s
# Requirement already satisfied (use --upgrade to upgrade): pyparsing>=2.0.1 in /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages (from pydotplus)
# Building wheels for collected packages: pydotplus
# done
#   Stored in directory: /Users/gcg/Library/Caches/pip/wheels/43/31/48/e1d60511537b50a8ec28b130566d2fbbe4ac302b0def4baa48
# Successfully built pydotplus
# Installing collected packages: pydotplus
# Successfully installed pydotplus-2.0.2

# %%
from sklearn.externals.six import StringIO
import pydotplus #pip install pydotplus

# %%
with open("iris.dot", 'w') as f:
    f = tree.export_graphviz(dt, out_file=f)

# %%
import os
os.unlink('iris.dot')

# %%
# !pip3 install GraphViz
# Out:
# Collecting GraphViz
#   Downloading graphviz-0.4.10-py2.py3-none-any.whl
# Installing collected packages: GraphViz
# Successfully installed GraphViz-0.4.10

# %%
import graphviz

# %%
dot_data = StringIO() 
tree.export_graphviz(dt, out_file=dot_data) #brew install graphviz
graph = pydotplus.graph_from_dot_data(dot_data.getvalue()) 
graph.write_pdf("iris.pdf")
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-29-1a1247c23941> in <module>()
#       2 tree.export_graphviz(dt, out_file=dot_data) #brew install graphviz
#       3 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ----> 4 graph.write_pdf("iris.pdf")
#
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/pydotplus/graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/pydotplus/graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# /Users/gcg/.virtualenvs/ddj/lib/python3.5/site-packages/pydotplus/graphviz.py in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# InvocationException: GraphViz's executables not found

# %%
from IPython.display import IFrame
IFrame("iris.pdf", width=800, height=800)

# %% [markdown]
# ## We can also do some feature normalization if we'd like

# %%
from sklearn.datasets import load_iris
from sklearn import preprocessing

iris = load_iris()
X = iris.data
y = iris.target
normalized_X = preprocessing.normalize(X) #we normalize the values on a scale of 0 to 1

list(zip(X,normalized_X))
