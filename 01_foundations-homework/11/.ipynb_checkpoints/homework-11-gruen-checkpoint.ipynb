# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# ## 1. I want to make sure my Plate ID is a string. Can't lose the leading zeroes!
# ## 2. I don't think anyone's car was built in 0AD. Discard the '0's as NaN.
# ## 3. I want the dates to be dates! Read the read_csv documentation to find out how to make pandas automatically parse dates.

# %%
col_types = "str"
df = pd.read_csv("mini_violations.csv", na_values={'Vehicle Year':"0", 'Date First Observed': "0", 'Vehicle Expiration Date': "0"}, low_memory=False, dtype=col_types, parse_dates=["Issue Date"])
#giving parse_time also "Vehicle Expiration Date" as a element, it did not convert it, thus left out and dealt with with .apply later

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 43 columns):
# Summons Number                       999 non-null object
# Plate ID                             999 non-null object
# Registration State                   999 non-null object
# Plate Type                           999 non-null object
# Issue Date                           999 non-null datetime64[ns]
# Violation Code                       999 non-null object
# Vehicle Body Type                    962 non-null object
# Vehicle Make                         975 non-null object
# Issuing Agency                       999 non-null object
# Street Code1                         999 non-null object
# Street Code2                         999 non-null object
# Street Code3                         999 non-null object
# Vehicle Expiration Date              644 non-null object
# Violation Location                   984 non-null object
# Violation Precinct                   999 non-null object
# Issuer Precinct                      999 non-null object
# Issuer Code                          999 non-null object
# Issuer Command                       999 non-null object
# Issuer Squad                         999 non-null object
# Violation Time                       995 non-null object
# Time First Observed                  115 non-null object
# Violation County                     936 non-null object
# Violation In Front Of Or Opposite    882 non-null object
# House Number                         854 non-null object
# Street Name                          993 non-null object
# Intersecting Street                  133 non-null object
# Date First Observed                  68 non-null object
# Law Section                          999 non-null object
# Sub Division                         999 non-null object
# Violation Legal Code                 4 non-null object
# Days Parking In Effect               999 non-null object
# From Hours In Effect                 999 non-null object
# To Hours In Effect                   999 non-null object
# Vehicle Color                        981 non-null object
# Unregistered Vehicle?                999 non-null object
# Vehicle Year                         571 non-null object
# Meter Number                         995 non-null object
# Feet From Curb                       999 non-null object
# Violation Post Code                  4 non-null object
# Violation Description                0 non-null object
# No Standing or Stopping Violation    0 non-null object
# Hydrant Violation                    0 non-null object
# Double Parking Violation             0 non-null object
# dtypes: datetime64[ns](1), object(42)
# memory usage: 335.7+ KB

# %%
print(df['Issue Date'][0])
# Out:
# 2013-08-04 00:00:00

# %%
df['Violation County'].value_counts()
# Out:
# K     384
# NY    283
# Q     177
# BX     69
# R      23
# Name: Violation County, dtype: int64

# %%
df.dtypes
# Out:
# Summons Number                               object
# Plate ID                                     object
# Registration State                           object
# Plate Type                                   object
# Issue Date                           datetime64[ns]
# Violation Code                               object
# Vehicle Body Type                            object
# Vehicle Make                                 object
# Issuing Agency                               object
# Street Code1                                 object
# Street Code2                                 object
# Street Code3                                 object
# Vehicle Expiration Date                      object
# Violation Location                           object
# Violation Precinct                           object
# Issuer Precinct                              object
# Issuer Code                                  object
# Issuer Command                               object
# Issuer Squad                                 object
# Violation Time                               object
# Time First Observed                          object
# Violation County                             object
# Violation In Front Of Or Opposite            object
# House Number                                 object
# Street Name                                  object
# Intersecting Street                          object
# Date First Observed                          object
# Law Section                                  object
# Sub Division                                 object
# Violation Legal Code                         object
# Days Parking In Effect                       object
# From Hours In Effect                         object
# To Hours In Effect                           object
# Vehicle Color                                object
# Unregistered Vehicle?                        object
# Vehicle Year                                 object
# Meter Number                                 object
# Feet From Curb                               object
# Violation Post Code                          object
# Violation Description                        object
# No Standing or Stopping Violation            object
# Hydrant Violation                            object
# Double Parking Violation                     object
# dtype: object

# %% [markdown]
# ## 4. "Date first observed" is a pretty weird column, but it seems like it has a date hiding inside. Using a function with .apply, transform the string (e.g. "20140324") into a Python date.
#
# --> Already done in the first step: "Make the 0's show up as NaN"
#
# As "Vehicle Expiration Date" has the same format as "Date First observed" will also convert it with the same method

# %%
df["Date First Observed"].head(40)
#format "Date First Observed": 20130719
type(df["Date First Observed"])
# Out:
# pandas.core.series.Series

# %%
import dateutil
from dateutil import parser
#https://dateutil.readthedocs.io/en/stable/parser.html
#dateutil.parser.parse(timestr, parserinfo=None)

# %%
#WHY IS IT A FLOAT? I DEFINED ALL COLUMNS TO BE STR!?
type(df["Date First Observed"][0])
# Out:
# float

# %%
def date_str_to_date(timestr):
    convert_date_str = str(timestr)
    try:
        return dateutil.parser.parse(convert_date_str)
    except: 
        return convert_date_str

# %%
df['date_first_observed'] = df["Date First Observed"].apply(date_str_to_date)

# %%
#format "Vehicle Expiration Date": 20140831

df['vehicle_expiration'] = df["Vehicle Expiration Date"].apply(date_str_to_date)

# %% [markdown]
# ## 5. "Violation time" is... not a time. Make it a time.

# %%
import time

def changing_time(messy_time):
    a = messy_time[0:2]
    b = messy_time[-3:-1]
    c = messy_time[-1:]
    d = a +":"+ b + c + "M"
    #return d
    try: 
        stripped_time = dateutil.parser.parse(d).time()
        return stripped_time
    except:
        return d

df['violation_time'] = df["Violation Time"].astype(str).apply(changing_time)

# %%
type(df['violation_time'][0])
# Out:
# datetime.time

# %% [markdown]
# ## 6. There sure are a lot of colors of cars, too bad so many of them are the same. Make "BLK" and "BLACK", "WT" and "WHITE", and any other combinations that you notice.

# %%
#df["Vehicle Color"].value_counts() 
df['vehicle_color'] = df["Vehicle Color"].replace(["WH", "WT", "WHT", "WHI"], "WHITE").replace(["BK", "BLK"], "BLACK").replace(["GY", "GRY", "GRAY"], "GREY").replace(["BL", "BLU"], "BLUE").replace("RD", "RED").replace(["OR","ORANG"], "ORANGE").replace(["GRN", "GR", "GN"], "GREEN").replace(["BR", "BRN", "BN", "BRWN"], "BROWN").replace(["SILVE", "SILVR", "SIL", "SL"],"SILVER").replace("GL", "GOLD").replace(["YELLO","YW"],"YELLOW").replace("TN", "TAN")

#TRIED FUNCTION AND LIST COMPREHENSION AND FOR LOOP, ALL THREW ERRORS AT SOME POINT

#def change_color(wrongspell, rightspell):
#    newdf = df[df["Vehicle Color"].replace(wrongspell, rightspell)]
#    return newdf
#change_color("WH", "WHITE")
#change_color("WHT", "WHITE")
#change_color("WT", "WHITE")

#wrong_spellings = ["WH", "WT", "WHT"]
#for spelling in wrong_spellings:
#    newdf["Vehicle Color"] = df["Vehicle Color"].replace(spelling, "WHITE")

#[df["Vehicle Color"].replace(spelling, "WHITE") for spelling in wrong_spellings]

# %%
df.columns
# Out:
# Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation', 'date_first_observed', 'vehicle_expiration',
#        'violation_time', 'vehicle_color'],
#       dtype='object')

# %% [markdown]
# ## 7. Join the data with the Parking Violations Code dataset from the NYC Open Data site.

# %%
# selecting the columns needed to answer the remaining questions 
# above manipulated columns vehicle_color and date_first_observed not included, as not needed
selection= df[['Summons Number', 'Plate ID', 'Registration State', 'Violation County', 'Issue Date', 'violation_time', 'Violation Code']]

# %%
# make table column names look neater/having the same structure (no blank spaces within name!!!)
selection.columns = ['summons_number', 'plate_id', 'registration_state', 'violation_county', 'issue_date', 'violation_time', 'violation_code']

# %%
selection
# Out:
#     summons_number  plate_id registration_state violation_county issue_date  \
# 0       1283294138   GBB9093                 NY              NaN 2013-08-04
# 1       1283294151   62416MB                 NY               NY 2013-08-04
# 2       1283294163   78755JZ                 NY               NY 2013-08-05
# 3       1283294175   63009MA                 NY               NY 2013-08-05
# 4       1283294187   91648MC                 NY               NY 2013-08-08
# 5       1283294217    T60DAR                 NJ               NY 2013-08-11
# 6       1283294229   GCR2838                 NY               NY 2013-08-11
# 7       1283983620    XZ764G                 NJ                K 2013-08-07
# 8       1283983631   GBH9379                 NY                K 2013-08-07
# 9       1283983667    MCL78B                 NJ                K 2013-07-18
# 10      1283983679    M367CN                 NY                K 2013-07-18
# 11      1283983734   GAR6813                 NY                K 2013-07-18
# 12      1283983771   GEN8674                 NY                K 2013-07-31
# 13      1283983825   GAC2703                 NY                K 2013-08-12
# 14      1286036800   40793JY                 NY              NaN 2013-07-05
# 15      1286123550   GAD1485                 NY                K 2013-08-12
# 16      1286246398   GFC5338                 NY                K 2013-07-26
# 17      1286246416   815M342                 MD                K 2013-07-30
# 18      1286248000   GJA3452                 NY                K 2013-07-23
# 19      1286282330   YZY6476                 NC                K 2013-07-29
# 20      1286282342    WBJ819                 LA                K 2013-08-07
# 21      1286289841   GAV9235                 NY                K 2013-07-20
# 22      1286654920    ZTR66R                 NJ               NY 2013-07-18
# 23      1286799648   GDE3973                 NY               NY 2013-07-20
# 24      1286807062   P193871                 IL                K 2013-08-10
# 25      1286807475   GGL6608                 NY                K 2013-07-26
# 26      1286807633   84301JU                 NY                K 2013-07-19
# 27      1286808807   HHG3545                 PA                K 2013-08-06
# 28      1287320491   50097JX                 NY               NY 2013-08-07
# 29      1287320570   GEJ9154                 NY                K 2013-08-06
# ..             ...       ...                ...              ...        ...
# 969     1334886817  T600324C                 NY                Q 2013-07-12
# 970     1334893391   GEF8039                 NY              NaN 2013-08-08
# 971     1334899332   GAR5973                 NY                Q 2013-05-28
# 972     1334899356     76860                 NY                Q 2013-07-11
# 973     1334900190    G44DBB                 NJ                Q 2013-06-06
# 974     1334960409   GCP7978                 NY              NaN 2013-07-16
# 975     1334965547  T606011C                 NY               BX 2013-08-18
# 976     1335085889   GEB4077                 NY                K 2013-08-05
# 977     1335086067    408861                 RI               NY 2013-08-04
# 978     1335087308    505GSB                 OK              NaN 2013-08-21
# 979     1335087436   GGF7010                 NY              NaN 2013-08-14
# 980     1335087618    XH208F                 99              NaN 2013-07-27
# 981     1335087930   GGB3579                 NY                K 2013-07-27
# 982     1335089433    49SD67                 NY                K 2013-08-05
# 983     1335089445   GDM5570                 NY                K 2013-08-20
# 984     1335089731    55RG48                 NY                K 2013-08-17
# 985     1335090538   GDF7589                 NY                K 2013-07-21
# 986     1335091440  PC613253                 99                K 2013-07-27
# 987     1335092730    82GN94                 NY                K 2013-08-17
# 988     1335092742    47RE79                 NY                K 2013-08-17
# 989     1335092754    78GX62                 NY                K 2013-08-17
# 990     1335092766    49SD33                 NY                K 2013-08-20
# 991     1335092778   GDU8731                 NY                K 2013-08-21
# 992     1335093072   GEN7535                 NY                K 2013-07-23
# 993     1335093199  T529952C                 NY                K 2013-08-01
# 994     1335093205   GBJ4073                 NY                K 2013-08-01
# 995     1335095342   JHA1050                 PA                K 2013-07-21
# 996     1335096139    72416R                 VA                K 2013-08-11
# 997     1335096140    HPJ538                 MS                K 2013-08-11
# 998     1335096152   HYW9707                 PA                K 2013-08-19
#
#     violation_time violation_code
# 0         07:52:00             46
# 1         12:40:00             46
# 2         12:43:00             46
# 3         14:32:00             46
# 4         12:39:00             41
# 5         18:17:00             14
# 6         19:41:00             14
# 7         04:25:00             24
# 8         04:37:00             24
# 9         08:39:00             24
# 10        08:45:00             24
# 11        09:07:00             24
# 12        17:14:00             24
# 13        18:56:00             24
# 14        23:45:00             14
# 15        17:46:00             20
# 16        11:42:00             14
# 17        07:24:00             20
# 18        07:58:00             14
# 19        07:36:00             20
# 20        08:47:00             17
# 21        11:20:00             50
# 22        10:20:00             50
# 23        15:24:00             40
# 24        10:18:00             40
# 25        07:43:00             40
# 26        08:50:00             14
# 27        09:15:00             20
# 28        10:23:00             40
# 29        11:20:00             51
# ..             ...            ...
# 969       14:28:00             17
# 970       11:29:00             14
# 971       10:59:00             20
# 972       10:50:00             20
# 973       02:00:00             20
# 974       08:55:00             20
# 975       19:30:00             40
# 976       13:21:00             24
# 977       13:15:00             24
# 978       21:50:00             20
# 979       01:53:00             24
# 980       15:50:00             20
# 981       21:53:00             41
# 982       23:30:00             51
# 983       20:10:00             20
# 984       20:40:00             51
# 985       20:45:00             24
# 986       21:25:00             24
# 987       19:00:00             51
# 988       19:00:00             51
# 989       19:00:00             51
# 990       19:40:00             51
# 991       01:20:00             24
# 992       00:40:00             24
# 993       00:05:00             50
# 994       21:50:00             14
# 995       14:31:00             40
# 996       14:13:00             24
# 997       14:20:00             24
# 998       16:27:00             24
#
# [999 rows x 7 columns]

# %%
# in atom I replaced all the $ by nothing -- seemed more time efficient than doing it in pandas ;) 

vc_set = pd.read_csv("DOF_Parking_Violation_Codes.csv", dtype="str")

vc_set.columns = ["code", "definition", "manhattan_below_96", "all_other_areas"]
vc_set
# Out:
#      code                                         definition  \
# 0      10  Stopping, standing or parking where a sign, st...
# 1      11  Hotel Loading/Unloading: Standing or parking w...
# 2      12  Snow Emergency: Standing or parking where stan...
# 3      13  Taxi Stand: Standing or parking where standing...
# 4      14  General No Standing: Standing or parking where...
# 5      16  Truck Loading/Unloading: Standing or parking w...
# 6      17  Authorized Vehicles Only: Standing or parking ...
# 7      18  Bus Lane: Standing or parking where standing i...
# 8      19  Bus Stop: Standing or parking where standing i...
# 9      20  General No Parking: No parking where parking i...
# 10     21  Street Cleaning: No parking where parking is n...
# 11     22  Hotel Loading/Unloading: No parking where park...
# 12     23  Taxi Stand: No parking where parking is not al...
# 13     24  Authorized Vehicles Only: No parking where par...
# 14     25  Standing at a commuter van stop, other than te...
# 15     26  Standing at a for-hire vehicle stop, other tha...
# 16     27  No parking in a handicapped zone (off-street o...
# 17     28                       Overtime standing (diplomat)
# 18     31  Standing of a non-commercial vehicle in a comm...
# 19     32  Parking at a broken or missing meter for longe...
# 20     33  "Feeding Meter" -- parking in a metered space ...
# 21     34  Expired Meter -- parking in a metered space wh...
# 22     35  Parking in a meter space for the purpose of di...
# 23  37-38  Muni Meter --\n(37) Parking in excess of the a...
# 24     39  Parking for longer than the maximum time permi...
# 25     69  Failing to show a muni-meter receipt, commerci...
# 26     40  Stopping, standing or parking closer than 15 f...
# 27     42  Parking in a Muni Metered space in a commercia...
# 28     43  Parking in a commercial metered zone in which ...
# 29     44  Parking in a commercial metered zone for longe...
# ..    ...                                                ...
# 54     71  Standing or parking a vehicle without showing ...
# 55     72  Standing or parking a vehicle with NY Plates a...
# 56     73  Standing or parking a vehicle showing an expir...
# 57     74  Standing or parking a vehicle without properly...
# 58     75  Standing or parking a vehicle in which the Lic...
# 59     77  Parking a bus, unless allowed by signs. A char...
# 60     78  Parking a Commercial Vehicle on a residential ...
# 61     79  For a bus without passengers, waiting at a cur...
# 62     80  Standing or parking a vehicle without head lam...
# 63     81                        No standing except diplomat
# 64     82  Standing or parking a Commercial Vehicle unles...
# 65     83  Standing or parking a vehicle which is not pro...
# 66     84  Parking a Commercial Vehicle on any city stree...
# 67     85  Parking a Commercial Vehicle more than 3 hours...
# 68     86  Standing or parking a vehicle to make pickups,...
# 69     89  Standing or parking a vehicle in the Garment D...
# 70     91  Parking in order to sell a vehicle by a person...
# 71     92  Parking in order to wash, grease, or repair a ...
# 72     93  Stopping, standing or parking on paved roadway...
# 73     94  Vehicle Release Agreement code associated with...
# 74     96  Standing or parking within 50 feet of the near...
# 75     97  Parking in a vacant lot. A vehicle may be park...
# 76     98  Standing or parking in front of a public or pr...
# 77     99  All other parking, standing or stopping violat...
# 78     04  Vehicles parked illegally south of Houston Str...
# 79     05      Failure to make a right turn from a bus lane.
# 80     06  Parking a tractor-trailer on a residential str...
# 81     07  Vehicles photographed going through a red ligh...
# 82     08               Vehicle idling in a restricted area.
# 83     09  Blocking an Intersection: Obstructing traffic ...
#
#                          manhattan_below_96  \
# 0                                      115
# 1                                      115
# 2                                       95
# 3                                      115
# 4                                      115
# 5                                       95
# 6                                       95
# 7                                      115
# 8                                      115
# 9                                       65
# 10                                      65
# 11                                      60
# 12                                      65
# 13                                      65
# 14                                     115
# 15                                     115
# 16                                     180
# 17                                      95
# 18                                     115
# 19                                      65
# 20                                      65
# 21                                      65
# 22                                      65
# 23                                      65
# 24                                      65
# 25                                      65
# 26                                     115
# 27                                      65
# 28                                      65
# 29                                      65
# ..                                      ...
# 54                                      65
# 55                                      65
# 56                                      65
# 57                                      65
# 58                                      65
# 59                                      65
# 60                                      65
# 61                                     115
# 62                                      60
# 63                                      95
# 64                                     115
# 65                                      65
# 66                                      65
# 67                                      65
# 68                                     115
# 69                                     115
# 70                                      65
# 71                                      65
# 72                                      65
# 73  100\n(Regular Tow, plus violation fine)
# 74                                      95
# 75                                      65
# 76                                      95
# 77                                     vary
# 78                                     115
# 79                                     115
# 80     1st Offense - 265\n2nd Offense - 515
# 81                                     50
# 82                                     115
# 83                                     115
#
#                          all_other_areas
# 0                                    115
# 1                                    115
# 2                                     95
# 3                                    115
# 4                                    115
# 5                                     95
# 6                                     95
# 7                                    115
# 8                                    115
# 9                                     60
# 10                                    45
# 11                                    60
# 12                                    60
# 13                                    60
# 14                                   115
# 15                                   115
# 16                                   180
# 17                                    95
# 18                                   115
# 19                                    35
# 20                                    35
# 21                                    35
# 22                                    35
# 23                                    35
# 24                                    60
# 25                                    65
# 26                                   115
# 27                                    35
# 28                                    35
# 29                                    35
# ..                                   ...
# 54                                    65
# 55                                    65
# 56                                    65
# 57                                    65
# 58                                    65
# 59                                    45
# 60                                    65
# 61                                   115
# 62                                    45
# 63                                    95
# 64                                   115
# 65                                    65
# 66                                    45
# 67                                    65
# 68                                   115
# 69                                   115
# 70                                    45
# 71                                    45
# 72                                    65
# 73  200 (Heavy Tow, plus violation fine)
# 74                                    95
# 75                                    45
# 76                                    95
# 77                                  vary
# 78                                   NaN
# 79                                   115
# 80  2nd Offense - 265\n2nd Offense - 515
# 81                                  50
# 82                                   115
# 83                                   115
#
# [84 rows x 4 columns]

# %%
combined_df = selection.merge (vc_set, left_on='violation_code', right_on='code')

# %%
combined_df.columns
# Out:
# Index(['summons_number', 'plate_id', 'registration_state', 'violation_county',
#        'issue_date', 'violation_time', 'violation_code', 'code', 'definition',
#        'manhattan_below_96', 'all_other_areas'],
#       dtype='object')

# %%
combined_df
# Out:
#     summons_number  plate_id registration_state violation_county issue_date  \
# 0       1283294138   GBB9093                 NY              NaN 2013-08-04
# 1       1283294151   62416MB                 NY               NY 2013-08-04
# 2       1283294163   78755JZ                 NY               NY 2013-08-05
# 3       1283294175   63009MA                 NY               NY 2013-08-05
# 4       1290834349   429J6JM                 NY                Q 2013-07-23
# 5       1290834374   42587JW                 NY                Q 2013-07-30
# 6       1291521665  YANKYJAM                 NY                K 2013-07-02
# 7       1293030739   GHG2484                 NY                Q 2013-08-11
# 8       1293100924   64195MC                 NY                K 2013-06-20
# 9       1293101151   54100JA                 NY               NY 2013-07-05
# 10      1293525625   GGP1847                 NY                K 2013-07-29
# 11      1294202492    XD377T                 NJ               NY 2013-07-25
# 12      1302446484    452WW4                 MA                K 2013-06-24
# 13      1302446538    4274WY                 CT                K 2013-07-10
# 14      1306112679   97732JZ                 NY                Q 2013-08-15
# 15      1306114172   91628MC                 NY                Q 2013-08-02
# 16      1306114184   84614JR                 NY                Q 2013-08-23
# 17      1306114196   62092JL                 NY                Q 2013-08-23
# 18      1306116235   GGU4798                 NY                Q 2013-07-27
# 19      1306206844   55197JJ                 NY               NY 2013-08-06
# 20      1307452577   55003JG                 NY               NY 2013-08-12
# 21      1307452590   40470JU                 99              NaN 2013-08-12
# 22      1321774722   61944JY                 NY              NaN 2013-07-17
# 23      1321774771   35210MB                 NY              NaN 2013-07-17
# 24      1321965783   GBN4223                 NY                K 2013-08-05
# 25      1325733878  T635444C                 NY               BX 2013-08-13
# 26      1325972393   GBX9511                 NY               NY 2013-07-14
# 27      1326475710   WZF5882                 NY                K 2013-08-11
# 28      1295546516   GCY5976                 NY                Q 2013-07-25
# 29      1295547089   62516JM                 NY                Q 2013-07-19
# ..             ...       ...                ...              ...        ...
# 959     1306632572   45940MD                 NY               BX 2013-08-01
# 960     1321688313  5X150411                 AL                Q 2013-07-15
# 961     1326367304   JJA6304                 PA                K 2013-07-30
# 962     1326367316    XZ758G                 NJ                K 2013-07-30
# 963     1326367330    XAUM69                 NJ                K 2013-07-30
# 964     1326367341    XT254Y                 NJ                K 2013-07-30
# 965     1326367377   ZBL9225                 PA                K 2013-08-09
# 966     1326367389   JJA6304                 PA                K 2013-08-09
# 967     1333437845   54059MC                 NY               NY 2013-07-28
# 968     1311447684    XK134N                 NJ                R 2013-07-21
# 969     1307949484   GEZ5475                 NY               NY 2013-08-11
# 970     1307953128    N34ASW                 NJ                R 2013-08-11
# 971     1308157344   GER6778                 NY                Q 2013-07-19
# 972     1334736820   GGN3919                 NY                K 2013-08-13
# 973     1307953141    85RS47                 NY                R 2013-08-15
# 974     1333925347   97431JZ                 NY               NY 2013-08-09
# 975     1307953852   GFP6251                 NY                R 2013-08-24
# 976     1334878444   GGB5893                 NY                K 2013-07-22
# 977     1325855789   GBJ1134                 NY                Q 2013-07-21
# 978     1295547478     72044                 RI                Q 2013-07-17
# 979     1295547480     9N77D                 NY                Q 2013-07-22
# 980     1295548021   GCG3830                 NY                Q 2013-07-24
# 981     1307964011     78439                 MA               NY 2013-07-26
# 982     1307964485   GAA1955                 NY               NY 2013-07-21
# 983     1311687713   7501500                 NY               NY 2013-07-26
# 984     1333609826   GCL1507                 NY                K 2013-07-18
# 985     1308157320   GFS4162                 NY                Q 2013-07-19
# 986     1333716310    N58APT                 NJ               NY 2013-07-07
# 987     1334012568    YUZ75Z                 NJ                Q 2013-07-29
# 988     1334032191    85677X                 IL                Q 2013-07-31
#
#     violation_time violation_code code  \
# 0         07:52:00             46   46
# 1         12:40:00             46   46
# 2         12:43:00             46   46
# 3         14:32:00             46   46
# 4         10:37:00             46   46
# 5         11:19:00             46   46
# 6         19:42:00             46   46
# 7         01:30:00             46   46
# 8         15:44:00             46   46
# 9         13:15:00             46   46
# 10        21:45:00             46   46
# 11        09:53:00             46   46
# 12        10:25:00             46   46
# 13        10:15:00             46   46
# 14        23:50:00             46   46
# 15        04:48:00             46   46
# 16        04:42:00             46   46
# 17        02:46:00             46   46
# 18        16:52:00             46   46
# 19        16:10:00             46   46
# 20        09:40:00             46   46
# 21        09:20:00             46   46
# 22        10:05:00             46   46
# 23        12:14:00             46   46
# 24        07:47:00             46   46
# 25        19:37:00             46   46
# 26        02:38:00             46   46
# 27        19:25:00             46   46
# 28        15:13:00             46   46
# 29        14:30:00             46   46
# ..             ...            ...  ...
# 959       23:45:00             78   78
# 960       21:47:00             78   78
# 961       04:23:00             78   78
# 962       04:30:00             78   78
# 963       04:35:00             78   78
# 964       04:37:00             78   78
# 965       03:35:00             78   78
# 966       03:36:00             78   78
# 967       02:55:00             78   78
# 968       22:06:00             78   78
# 969       19:22:00             39   39
# 970       15:31:00             61   61
# 971       13:14:00             61   61
# 972       08:01:00             61   61
# 973       18:41:00             45   45
# 974       13:31:00             45   45
# 975       13:28:00             27   27
# 976       11:31:00             27   27
# 977       14:00:00             67   67
# 978       17:55:00             67   67
# 979       14:15:00             67   67
# 980       15:55:00             67   67
# 981       20:14:00             67   67
# 982       16:45:00             67   67
# 983       06:47:00             67   67
# 984       06:45:00             75   75
# 985       12:29:00             80   80
# 986       00:10:00             13   13
# 987       15:10:00             13   13
# 988       11:10:00             99   99
#
#                                             definition manhattan_below_96  \
# 0    Standing or parking on the roadway side of a v...               115
# 1    Standing or parking on the roadway side of a v...               115
# 2    Standing or parking on the roadway side of a v...               115
# 3    Standing or parking on the roadway side of a v...               115
# 4    Standing or parking on the roadway side of a v...               115
# 5    Standing or parking on the roadway side of a v...               115
# 6    Standing or parking on the roadway side of a v...               115
# 7    Standing or parking on the roadway side of a v...               115
# 8    Standing or parking on the roadway side of a v...               115
# 9    Standing or parking on the roadway side of a v...               115
# 10   Standing or parking on the roadway side of a v...               115
# 11   Standing or parking on the roadway side of a v...               115
# 12   Standing or parking on the roadway side of a v...               115
# 13   Standing or parking on the roadway side of a v...               115
# 14   Standing or parking on the roadway side of a v...               115
# 15   Standing or parking on the roadway side of a v...               115
# 16   Standing or parking on the roadway side of a v...               115
# 17   Standing or parking on the roadway side of a v...               115
# 18   Standing or parking on the roadway side of a v...               115
# 19   Standing or parking on the roadway side of a v...               115
# 20   Standing or parking on the roadway side of a v...               115
# 21   Standing or parking on the roadway side of a v...               115
# 22   Standing or parking on the roadway side of a v...               115
# 23   Standing or parking on the roadway side of a v...               115
# 24   Standing or parking on the roadway side of a v...               115
# 25   Standing or parking on the roadway side of a v...               115
# 26   Standing or parking on the roadway side of a v...               115
# 27   Standing or parking on the roadway side of a v...               115
# 28   Standing or parking on the roadway side of a v...               115
# 29   Standing or parking on the roadway side of a v...               115
# ..                                                 ...                ...
# 959  Parking a Commercial Vehicle on a residential ...                65
# 960  Parking a Commercial Vehicle on a residential ...                65
# 961  Parking a Commercial Vehicle on a residential ...                65
# 962  Parking a Commercial Vehicle on a residential ...                65
# 963  Parking a Commercial Vehicle on a residential ...                65
# 964  Parking a Commercial Vehicle on a residential ...                65
# 965  Parking a Commercial Vehicle on a residential ...                65
# 966  Parking a Commercial Vehicle on a residential ...                65
# 967  Parking a Commercial Vehicle on a residential ...                65
# 968  Parking a Commercial Vehicle on a residential ...                65
# 969  Parking for longer than the maximum time permi...                65
# 970  Except where angle parking is allowed, stoppin...                65
# 971  Except where angle parking is allowed, stoppin...                65
# 972  Except where angle parking is allowed, stoppin...                65
# 973  Stopping, standing or parking in a traffic lan...               115
# 974  Stopping, standing or parking in a traffic lan...               115
# 975  No parking in a handicapped zone (off-street o...               180
# 976  No parking in a handicapped zone (off-street o...               180
# 977              Parking in front of a pedestrian ramp               165
# 978              Parking in front of a pedestrian ramp               165
# 979              Parking in front of a pedestrian ramp               165
# 980              Parking in front of a pedestrian ramp               165
# 981              Parking in front of a pedestrian ramp               165
# 982              Parking in front of a pedestrian ramp               165
# 983              Parking in front of a pedestrian ramp               165
# 984  Standing or parking a vehicle in which the Lic...                65
# 985  Standing or parking a vehicle without head lam...                60
# 986  Taxi Stand: Standing or parking where standing...               115
# 987  Taxi Stand: Standing or parking where standing...               115
# 988  All other parking, standing or stopping violat...               vary
#
#     all_other_areas
# 0               115
# 1               115
# 2               115
# 3               115
# 4               115
# 5               115
# 6               115
# 7               115
# 8               115
# 9               115
# 10              115
# 11              115
# 12              115
# 13              115
# 14              115
# 15              115
# 16              115
# 17              115
# 18              115
# 19              115
# 20              115
# 21              115
# 22              115
# 23              115
# 24              115
# 25              115
# 26              115
# 27              115
# 28              115
# 29              115
# ..              ...
# 959              65
# 960              65
# 961              65
# 962              65
# 963              65
# 964              65
# 965              65
# 966              65
# 967              65
# 968              65
# 969              60
# 970              45
# 971              45
# 972              45
# 973             115
# 974             115
# 975             180
# 976             180
# 977             165
# 978             165
# 979             165
# 980             165
# 981             165
# 982             165
# 983             165
# 984              65
# 985              45
# 986             115
# 987             115
# 988            vary
#
# [989 rows x 11 columns]

# %% [markdown]
# ## 8. How much money did NYC make off of parking violations?

# %%
all_fines = combined_df["manhattan_below_96"]
all_list = all_fines.sum().split(" ")

cleaned_fines =[]
for fine in all_list:
    try:
        int_fine = int(fine)
        cleaned_fines.append(int_fine)
    except:
        continue

money_nyc = sum(cleaned_fines)
print("NYC makes at least", money_nyc, " US-Dollar off parking violations.")
# Out:
# NYC makes at least 84270  US-Dollar off parking violations.

# %% [markdown]
# ## 9. What's the most lucrative kind of parking violation? The most frequent?

# %%
#most lucrative:
combined_df["manhattan_below_96"].value_counts()
# Out:
# 65                                         535
# 115                                        314
# 95                                         125
# 165                                          7
# 100\n(Regular Tow, plus violation fine)      4
# 180                                          2
# 60                                           1
# vary                                         1
# Name: manhattan_below_96, dtype: int64

# %%
combined_df["all_other_areas"].value_counts()
# Out:
# 45                                      391
# 115                                     314
# 95                                      125
# 60                                      117
# 65                                       28
# 165                                       7
# 200 (Heavy Tow, plus violation fine)      4
# 180                                       2
# vary                                      1
# Name: all_other_areas, dtype: int64

# %%
combined_df[combined_df["all_other_areas"] == "200 (Heavy Tow, plus violation fine)"]
# Out:
#     summons_number plate_id registration_state violation_county issue_date  \
# 544     6020309034  GEW4836                 99              NaN 2013-07-18
# 545     6020310784   447ZRW                 CT              NaN 2013-07-20
# 546     6020314583  87336JV                 PA              NaN 2013-07-26
# 547     6020342748   HWD923                 SC              NaN 2013-07-22
#
#     violation_time violation_code code  \
# 544        na:nanM             94   94
# 545        na:nanM             94   94
# 546        na:nanM             94   94
# 547        na:nanM             94   94
#
#                                             definition  \
# 544  Vehicle Release Agreement code associated with...
# 545  Vehicle Release Agreement code associated with...
# 546  Vehicle Release Agreement code associated with...
# 547  Vehicle Release Agreement code associated with...
#
#                           manhattan_below_96  \
# 544  100\n(Regular Tow, plus violation fine)
# 545  100\n(Regular Tow, plus violation fine)
# 546  100\n(Regular Tow, plus violation fine)
# 547  100\n(Regular Tow, plus violation fine)
#
#                           all_other_areas
# 544  200 (Heavy Tow, plus violation fine)
# 545  200 (Heavy Tow, plus violation fine)
# 546  200 (Heavy Tow, plus violation fine)
# 547  200 (Heavy Tow, plus violation fine)

# %% [markdown]
# ** The highest fine of 200 Dollar is given outside of Manhattan and is associated with the "Violation Code" of 46 **

# %%
#to find out row index of Violation code 46:
vc_set['code'].head(40)

#find out the definition of 
vc_set.loc[31]["definition"]
# Out:
# 'Standing or parking on the roadway side of a vehicle stopped, standing or parked at the curb; in other words\xa0also known as "double parking". However,\xa0a person may stand a Commercial Vehicle alongside a vehicle parked at the curb at such locations and during such hours that stopping, standing and parking is allowed when quickly making pickups, deliveries or service calls. This is allowed if there is no parking space or marked loading zone on either side of the street within 100 feet. "Double parking" any type of vehicle is not allowed in Midtown Manhattan (the area from 14th Street to 60th Street, between First Avenue and Eighth Avenue inclusive). Midtown double parking is not allowed between 7:00am\xa0 – 7:00pm daily except Sundays. (See Code 47.)'

# %%
#most frequent:
combined_df['violation_code'].describe()
# Out:
# count     989
# unique     29
# top        21
# freq      387
# Name: violation_code, dtype: object

# %% [markdown]
# **Most freqent is "Violation code" 21, occurring with a frequency of 387**

# %%
#to find out row index of Violation code 21:
#vc_set['code']

#find out the definition of 
vc_set.loc[10]["definition"]
# Out:
# 'Street Cleaning: No parking where parking is not allowed by sign, street marking or traffic control device.'

# %% [markdown]
# ## 10. New Jersey has bad drivers, but does it have bad parkers, too? How much money does NYC make off of all non-New York vehicles?

# %% [markdown]
# Thoughts: 1) Group by Registration State 2) sum up fare for all_other_areas

# %%
all_non_ny = combined_df[combined_df["registration_state"] != 'NY']
fines_non_ny = all_non_ny['all_other_areas']
fine_list = []
for fine in fines_non_ny:
    clean_fine = fine.replace(' (Heavy Tow, plus violation fine)', '').replace('vary','')
    try:
        fine_list.append(int(clean_fine))
    except:
        continue

sum_fines = sum(fine_list)
print("NYC makes at least", sum_fines, "US-Dollar from vehicles that are not registered in NY")
# Out:
# NYC makes at least 30245 US-Dollar from vehicles that are not registered in NY

# %% [markdown]
# ## 11. Make a chart of the top few.

# %%
def cleaning(value):
    if "(" in value:
        return 100
    if "vary" in value:
        return 2
    else:
        return int(value)

# %%
combined_df['manhattan_cleaned_fines'] = combined_df['manhattan_below_96'].apply(cleaning)

# %%
plt.style.use('ggplot')
combined_df.groupby(by='registration_state')['manhattan_cleaned_fines'].sum().sort_values().plot(kind='barh', figsize=(20,10))

# %% [markdown]
# ## 12. What time of day do people usually get their tickets? You can break the day up into several blocks - for example 12am-6am, 6am-12pm, 12pm-6pm, 6pm-12am.

# %%
type(combined_df['violation_time'][0])
# Out:
# datetime.time

# %%
print(combined_df['violation_time'][0])
# Out:
# 07:52:00

# %%
combined_df['violation_time'][0].hour
# Out:
# 7

# %%
def time_to_hour(value):
    try:
        return value.hour
    except:
        pass

# %%
combined_df["violation_hour"] = combined_df['violation_time'].apply(time_to_hour)
combined_df.head(3)
# Out:
#   summons_number plate_id registration_state violation_county issue_date  \
# 0     1283294138  GBB9093                 NY              NaN 2013-08-04
# 1     1283294151  62416MB                 NY               NY 2013-08-04
# 2     1283294163  78755JZ                 NY               NY 2013-08-05
#
#   violation_time violation_code code  \
# 0       07:52:00             46   46
# 1       12:40:00             46   46
# 2       12:43:00             46   46
#
#                                           definition manhattan_below_96  \
# 0  Standing or parking on the roadway side of a v...               115
# 1  Standing or parking on the roadway side of a v...               115
# 2  Standing or parking on the roadway side of a v...               115
#
#   all_other_areas  manhattan_cleaned_fines  violation_hour
# 0             115                      115             7.0
# 1             115                      115            12.0
# 2             115                      115            12.0

# %%
combined_df.groupby('violation_hour').count()['summons_number'].plot(kind="bar", figsize=(20,10))
plt.savefig('parkingtickets_hour.pdf', transparent=True)

# %%
combined_df['violation_hour'].hist(bins=4)

# %% [markdown]
# ## 13. What's the average ticket cost in NYC?

# %%
number_of_all_tickets = combined_df['manhattan_below_96'].count()
number_of_all_tickets
# Out:
# 989

# %%
# taking the total money NYC makes from question 8  -- stored in variable "money_nyc"
average_ticket_cost = money_nyc/number_of_all_tickets
print("The average ticket cost in NYC is", round(average_ticket_cost), "US-dollar.")
# Out:
# The average ticket cost in NYC is 85.0 US-dollar.

# %% [markdown]
# ## 14. Make a graph of the number of tickets per day.

# %%
combined_df.groupby('issue_date').count()
combined_df.groupby('issue_date').count()['summons_number']
plt.style.use('ggplot')
combined_df.groupby('issue_date').count()['summons_number'].plot(kind='bar', figsize=(20,10))

# %% [markdown]
# ## 15. Make a graph of the amount of revenue collected per day.

# %%
#groupby date, sum revenue

# %%
copy_df = combined_df
copy_df.index = copy_df['issue_date']

copy_df.groupby("issue_date")['manhattan_cleaned_fines'].sum().plot(kind='bar', figsize=(20,10))

# %%
type(dates_frame['issue_date'][0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-6d808b7040db> in <module>()
# ----> 1 type(dates_frame['issue_date'][0])
#
# NameError: name 'dates_frame' is not defined

# %%
dates_frame

# %%
dates_frame = combined_df[combined_df['issue_date'] == combined_df['issue_date']]
rashida = dates_frame.groupby('issue_date')
rashida.head()

# %%
dates_frame = combined_df[combined_df['issue_date'] == combined_df['issue_date']]
by_date = dates_frame.groupby('issue_date')
type(by_date)
[date[0] for date in by_date["issue_date"]]
# [date for date in dates_frame["issue_date"]]

# %%
# group by date, sum fines per day

dates_frame = combined_df[combined_df['issue_date'] == combined_df['issue_date']]
by_date = dates_frame.groupby('issue_date')

by_dates_list = []
for value in by_date['manhattan_below_96'].sum():
    cleaned_value_list = value.replace("(Regular Tow, plus violation fine)", "").replace("vary", "").split()
    revenue_int_list = [int(value) for value in cleaned_value_list]
    revenue_sum = sum(revenue_int_list)
    individual_date = [date[0] for date in by_date["issue_date"]]
    date_dict={'date': "individual_date", 'revenue': revenue_sum}
    by_dates_list.append(date_dict)

by_dates_list

# %%
by_dates_df = pd.DataFrame(by_dates_list)
by_dates_df.plot(kind='bar', figsize=(20,10))

# %% [markdown]
# ## 16. Manually construct a dataframe out of https://dmv.ny.gov/statistic/2015licinforce-web.pdf (only NYC boroughts - bronx, queens, manhattan, staten island, brooklyn), having columns for borough name, abbreviation, and number of licensed drivers.

# %%
licensed_drivers = pd.read_csv("licensed_drivers.csv")
selection_licensed = licensed_drivers.tail(5)[["County", "Total"]]
selection_licensed

# %%
abbreviation = [{'state': "Staten Island", 'abbreviation': "K"}, {'state': "Brooklyn", 'abbreviation': "R"}, {'state':"Queens", 'abbreviation':"Q"}, {'state':"Bronx", 'abbreviation': "BX"}, {'state':"New York", 'abbreviation':"NY"}]
abbrev_table = pd.DataFrame(abbreviation)
abbrev_table

# %%
joined_table = abbrev_table.merge(selection_licensed, left_on="state", right_on="County")
licensed_df = joined_table[['County', 'abbreviation', 'Total']]
licensed_df.columns = ("borough name", "abbreviation", "number of licensed drivers")
licensed_df

# %% [markdown]
# ## 17. What's the parking-ticket-cost-per-licensed-driver in each borough of NYC? Do this with pandas and the dataframe you just made, not with your head!

# %%
#1) Get total violation cost per borough
#2) Divide it by number of licensed drivers

# %%
df_17 = combined_df[['summons_number', 'violation_county', 'manhattan_below_96', 'all_other_areas']]
df_17

# %%
fine_dict_list = []
def get_fines(a,b):
    viol = df_17[df_17['violation_county'] == a]
    fines = viol[b]

    fines_list = []
    for fine in fines:
        try:
            fines_list.append(int(fine))
        except:
            continue
    fine_per_borough = sum(fines_list)
    dict_fines = {'state': a, 'total_fines_in_borough': fine_per_borough}
    fine_dict_list.append(dict_fines)

fines_per_borough = fine_dict_list

get_fines('NY', 'manhattan_below_96')
get_fines('K', 'all_other_areas')
get_fines('BX', 'all_other_areas')
get_fines('R', 'all_other_areas')
get_fines('Q', 'all_other_areas')

# %%
fines_per_borough

# %%
borough_fines = pd.DataFrame(fines_per_borough)

# %%
joined_df = licensed_df.merge(borough_fines, left_on="abbreviation", right_on="state")
joined_df

# %%
joined_df['parking-ticket-cost-per-licensed-driver'] = joined_df['total_fines_in_borough'] / joined_df['number of licensed drivers']

# %%
joined_df

# %% [markdown]
# Either my calculation went wrong somewhere or the fines are collected just by a very few drivers.
